# %%
import os
import os.path as osp

import time
from PIL import Image
import numpy as np

# %%
data_path = osp.join('.', 'data')
equi_path = osp.join(data_path, 'equi2.png')

# %%
equi_img = Image.open(equi_path)
equi_img = equi_img.convert('RGB')
equi = np.asarray(equi_img)

# %%
from matplotlib.pyplot import imshow
# %matplotlib inline

# %%
imshow(equi)

# %% [markdown]
# ## manipulate image

# %%
equi = np.transpose(equi, (2,0,1))
equi.shape
# Out:
# (3, 1920, 3840)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from equilib.equi2equi.equi2equi_numpy.equi2equi import Equi2Equi

# %%
equi2equi = Equi2Equi(h_equi=equi.shape[1], w_equi=equi.shape[2])

# %%
rot = {
    'roll': 0.,
    'pitch': 0.,
    'yaw': np.pi/4,
}

# %%
sample = equi2equi(src=equi, rot=rot)

# %%
sample = np.transpose(sample, (1,2,0))
sample = sample.astype('uint8')
print(sample.shape)
print(sample.dtype)
# Out:
# (1920, 3840, 3)
# uint8

# %%
imshow(sample)

# %%
from pano2pers_numpy import faster_sample

# %%
sampled = faster_sample(pano, grid, mode='bilinear')

# %%
new_pano = np.transpose(sampled, (1,2,0))

# %%
imshow(new_pano)
