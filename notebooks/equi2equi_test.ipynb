# %%
import os
import os.path as osp

import time
from PIL import Image
import numpy as np

import torch
from torchvision import transforms

# %%
data_path = osp.join('.', 'data')
equi_path = osp.join(data_path, 'equi2.png')

# %%
equi_img = Image.open(equi_path)
equi_img = equi_img.convert('RGB')
equi = np.asarray(equi_img)

# %%
to_tensor = transforms.Compose([
    transforms.ToTensor(),
])
to_PIL = transforms.Compose([
    transforms.ToPILImage(),
])

# %%
equi_torch = to_tensor(equi)

# %%
from matplotlib.pyplot import imshow
# %matplotlib inline

# %%
imshow(equi)

# %% [markdown]
# ## manipulate image

# %%
equi = np.transpose(equi, (2,0,1))
equi.shape
# Out:
# (3, 1920, 3840)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from equilib.equi2equi import NumpyEqui2Equi, TorchEqui2Equi

# %%
equi2equi = TorchEqui2Equi(h_out=640, w_out=1280)

# %%
rot = {
    'roll': 0.,
    'pitch': np.pi/4,
    'yaw': np.pi/4,
}

# %%
sample = equi2equi(src=equi_torch, rot=rot)

# %%
sample = to_PIL(sample)

# %%
imshow(sample)
